# %%
import goldenrecord

#filepath = "../data/mitdwh/"
filepath = "../data/author/"
cname = "cluster_id"
outfilepath = "./mitdwh_updated.csv"

consolidation = goldenrecord.Consolidation(filepath, cname)
num_of_tables = consolidation.number_of_tables
for i in range(num_of_tables):
  str_noc = consolidation.TryNextTable(i)
  for col_id in range(int(str_noc)):

    if col_id == consolidation.cluster_id_col:
      continue

    message1 = consolidation.ProfileColumn(i, col_id)
    print(message1)

    skip = input()
    if skip != "1" and skip != "2" and skip != "3" and skip != "4" and skip != "5":
      continue

    message2 = consolidation.TryNextColumn(i, col_id, skip)
    print(message2)

    applied_group_num = 0 

    var = 1 
    while var == 1:
      message3 = consolidation.ShowNextCluster()
      strs = message3.split('\t', 2)
      max_group_id = int(strs[0])
      max_count = int(strs[1])
      print(strs[2])
      if max_count == 0:
        print("Done with current column\n")
        break

      choice = input()
      if choice == "4":
        print("Done with current column\n")
        break

      message4 = consolidation.ApplyCluster(i, col_id, applied_group_num, max_group_id, choice)
      applied_group_num = applied_group_num + 1
      print(message4)

  consolidation.MaterializeTable(i, outfilepath)
  print("Successfully Exit!\n")
  break
# Out:
# looking for rules for table book.csv at column 0
# number of clusters 1265
# avg size 26.8545
# column: source_id
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table book.csv at column 2
# number of clusters 1265
# avg size 26.8545
# column: bookname
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table book.csv at column 3
# number of clusters 1265
# avg size 26.8545
# column: author
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 1
# Number of Rules Generated: 37984
# Number of Rules In Use: 23465
# Number of Groups: 10459
#
#
#
# group: ------
# [$$, 1, Start_Token, 1] --- [$$, 1, Punctuation, 0]
# [$^END_T^$, -1, Very_Special_for_Path, 0] --- [$^END_T^$, -1, Very_Special_for_Path, 1]
#
#
# 22: |lippman,|-->|lippman| x17
# 37: |knuth,|-->|knuth| x14
# 42: |foley,|-->|foley| x13
# 60: |eric,|-->|eric| x11
# 66: |triad,|-->|triad| x10
# 70: |huston,|-->|huston| x10
# 84: |yuan,|-->|yuan| x9
# 91: |shelford,|-->|shelford| x9
# 96: |denning,|-->|denning| x9
# 101: |ellis,|-->|ellis| x9
# 103: |singh,|-->|singh| x9
# 110: |john,|-->|john| x8
# 111: |english,|-->|english| x8
# 118: |david,|-->|david| x8
# 121: |slatin,|-->|slatin| x8
# 135: |campione,|-->|campione| x8
# 138: |bowman,|-->|bowman| x8
# 141: |chaudhri,|-->|chaudhri| x8
# 143: |raheem,|-->|raheem| x8
# 152: |mellor,|-->|mellor| x7
# 159: |bodoff,|-->|bodoff| x7
# 160: |leondes,|-->|leondes| x7
# 163: |tavares,|-->|tavares| x7
# 164: |rector,|-->|rector| x7
# 165: |jacobson,|-->|jacobson| x7
# 186: |kruse,|-->|kruse| x7
# 190: |carter,|-->|carter| x7
# 192: |graham,|-->|graham| x7
# 200: |brown,|-->|brown| x6
# 204: |sonkin,|-->|sonkin| x6
# 228: |gosling,|-->|gosling| x6
# 236: |walrath,|-->|walrath| x6
# 265: |martin,|-->|martin| x6
# 268: |filman,|-->|filman| x6
# 269: |white,|-->|white| x6
# 276: |brydon,|-->|brydon| x6
# 332: |richard,|-->|richard| x5
# 335: |sells,|-->|sells| x5
# 340: |farmer,|-->|farmer| x5
# 347: |viega,|-->|viega| x5
# 354: |lientz,|-->|lientz| x5
# 363: |riordan,|-->|riordan| x5
# 370: |paul,|-->|paul| x5
# 376: |abrams,|-->|abrams| x5
# 401: |meyers,|-->|meyers| x5
# 403: |yao,|-->|yao| x5
# 424: |henderson,|-->|henderson| x5
# 431: |greg,|-->|greg| x5
# 437: |stewart,|-->|stewart| x5
# 454: |microsystems,|-->|microsystems| x5
# 456: |clayberg,|-->|clayberg| x5
# 457: |james,|-->|james| x5
# 458: |bill,|-->|bill| x5
# 459: |michael,|-->|michael| x5
# 468: |mcgraw,|-->|mcgraw| x4
# 557: |eeles,|-->|eeles| x4
# 562: |wiegers,|-->|wiegers| x4
# 572: |ball,|-->|ball| x4
# 573: |seacord,|-->|seacord| x4
# 580: |deitel,|-->|deitel| x4
# 582: |arnold,|-->|arnold| x4
# 593: |armstrong,|-->|armstrong| x4
# 626: |stevens,|-->|stevens| x4
# 630: |chan,|-->|chan| x4
# 634: |kroll,|-->|kroll| x4
# 635: |mark,|-->|mark| x4
# 658: |geary,|-->|geary| x4
# 688: |inderjeet,|-->|inderjeet| x4
# 713: |fenner,|-->|fenner| x4
# 729: |andrew,|-->|andrew| x4
# 738: |clark,|-->|clark| x4
# 748: |chris,|-->|chris| x4
# 761: |abrahams,|-->|abrahams| x4
# 770: |bloch,|-->|bloch| x4
# 772: |granville,|-->|granville| x4
# 788: |robert,|-->|robert| x4
# 791: |murray,|-->|murray| x4
# 807: |holzner,|-->|holzner| x3
# 822: |chu,|-->|chu| x3
# 829: |fertitta,|-->|fertitta| x3
# 849: |carlton,|-->|carlton| x3
# 854: |andrews,|-->|andrews| x3
# 856: |kaplan,|-->|kaplan| x3
# 880: |hausman,|-->|hausman| x3
# 882: |maher,|-->|maher| x3
# 888: |ferdinandi,|-->|ferdinandi| x3
# 890: |peter,|-->|peter| x3
# 897: |platt,|-->|platt| x3
# 907: |patrick,|-->|patrick| x3
# 908: |bejtlich,|-->|bejtlich| x3
# 915: |stein,|-->|stein| x3
# 922: |pohl,|-->|pohl| x3
# 929: |li,|-->|li| x3
# 936: |don,|-->|don| x3
# 980: |barnes,|-->|barnes| x3
# 992: |bob,|-->|bob| x3
# 1014: |kelley,|-->|kelley| x3
# 1018: |lescher,|-->|lescher| x3
# 1031: |adams,|-->|adams| x3
# 1084: |mathers,|-->|mathers| x3
# 1108: |hoglund,|-->|hoglund| x3
# 1110: |patterson,|-->|patterson| x3
# 1112: |snader,|-->|snader| x3
# 1152: |raymond,|-->|raymond| x3
# 1188: |jennifer,|-->|jennifer| x3
# 1204: |falkner,|-->|falkner| x3
# 1216: |schneider,|-->|schneider| x3
# 1237: |dan,|-->|dan| x3
# 1246: |shukla,|-->|shukla| x3
# 1283: |josuttis,|-->|josuttis| x3
# 1293: |sutter,|-->|sutter| x3
# 1324: |zhao,|-->|zhao| x3
# 1328: |jones,|-->|jones| x3
# 1337: |skonnard,|-->|skonnard| x3
# 1352: |beauchemin,|-->|beauchemin| x3
# 1353: |douglass,|-->|douglass| x3
# 1399: |burdman,|-->|burdman| x3
# 1401: |joy,|-->|joy| x3
# 1409: |cockburn,|-->|cockburn| x3
# 1416: |gagne,|-->|gagne| x3
# 1417: |snyder,|-->|snyder| x3
# 1422: |barnett,|-->|barnett| x3
# 1428: |hart,|-->|hart| x3
# 1478: |mary,|-->|mary| x2
# 1526: |wang,|-->|wang| x2
# 1532: |henrik,|-->|henrik| x2
# 1564: |durant,|-->|durant| x2
# 1622: |harwood,|-->|harwood| x2
# 1633: |berglund,|-->|berglund| x2
# 1680: |box,|-->|box| x2
# 1688: |rubin,|-->|rubin| x2
# 1716: |goleniewski,|-->|goleniewski| x2
# 1762: |cohen,|-->|cohen| x2
# 1769: |fischer,|-->|fischer| x2
# 1809: |londer,|-->|londer| x2
# 1854: |gavrilenko,|-->|gavrilenko| x2
# 1860: |lippert,|-->|lippert| x2
# 1985: |lai,|-->|lai| x2
# 1995: |fosner,|-->|fosner| x2
# 2019: |roger,|-->|roger| x2
# 2024: |scanlon,|-->|scanlon| x2
# 2026: |chappell,|-->|chappell| x2
# 2044: |hersent,|-->|hersent| x2
# 2058: |nielsen,|-->|nielsen| x2
# 2098: |branigan,|-->|branigan| x2
# 2116: |wagner,|-->|wagner| x2
# 2117: |crume,|-->|crume| x2
# 2152: |dam,|-->|dam| x2
# 2213: |bishop,|-->|bishop| x2
# 2237: |lee,|-->|lee| x2
# 2257: |per,|-->|per| x2
# 2290: |spinellis,|-->|spinellis| x2
# 2330: |ernst,|-->|ernst| x2
# 2371: |jean,|-->|jean| x2
# 2448: |jeff,|-->|jeff| x2
# 2450: |kifer,|-->|kifer| x2
# 2699: |carvey,|-->|carvey| x2
# 2846: |jim,|-->|jim| x2
# 2923: |kanerva,|-->|kanerva| x2
# 2937: |hamacher,|-->|hamacher| x2
# 2955: |ramachandran,|-->|ramachandran| x2
# 2973: |steele,|-->|steele| x2
# 2990: |langr,|-->|langr| x2
# 2997: |zheng,|-->|zheng| x2
# 3113: |klette,|-->|klette| x2
# 3129: |craig,|-->|craig| x2
# 3170: |rubel,|-->|rubel| x2
# 3186: |carrier,|-->|carrier| x2
# 3207: |feiner,|-->|feiner| x2
# 3222: |angelika,|-->|angelika| x2
# 3229: |luebke,|-->|luebke| x2
# 3244: |vandevoorde,|-->|vandevoorde| x2
# 3332: |huml,|-->|huml| x2
# 3348: |joe,|-->|joe| x2
# 3373: |varshney,|-->|varshney| x2
# 3433: |carlson,|-->|carlson| x2
# 3447: |herb,|-->|herb| x2
# 3463: |alexandrescu,|-->|alexandrescu| x2
# 3464: |christopher,|-->|christopher| x2
# 3515: |fox,|-->|fox| x2
# 3558: |vladimirov,|-->|vladimirov| x2
# 3625: |kirk,|-->|kirk| x2
# 3693: |bjarne,|-->|bjarne| x2
# 3697: |reddy,|-->|reddy| x2
# 3716: |debbie,|-->|debbie| x2
# 3737: |marks,|-->|marks| x2
# 3741: |stephen,|-->|stephen| x2
# 3750: |sean,|-->|sean| x2
# 3756: |binstock,|-->|binstock| x2
# 3819: |the,|-->|the| x2
# 3837: |harold,|-->|harold| x2
# 4038: |campbell,|-->|campbell| x1
# 4250: |houston,|-->|houston| x1
# 4678: |mckean,|-->|mckean| x1
# 4714: |bragg,|-->|bragg| x1
# 5065: |vranesic,|-->|vranesic| x1
# 5136: |han,|-->|han| x1
# 5145: |al,|-->|al| x1
# 5174: |jiawei,|-->|jiawei| x1
# 5201: |hancock,|-->|hancock| x1
# 5223: |goldhamer,|-->|goldhamer| x1
# 5268: |courage,|-->|courage| x1
# 5443: |moo,|-->|moo| x1
# 5547: |coulthard,|-->|coulthard| x1
# 5569: |steven,|-->|steven| x1
# 5707: |shashi,|-->|shashi| x1
# 5713: |bradner,|-->|bradner| x1
# 5736: |malvino,|-->|malvino| x1
# 5898: |aura,|-->|aura| x1
# 6047: |ragsdale,|-->|ragsdale| x1
# 6068: |feil,|-->|feil| x1
# 6089: |tobias,|-->|tobias| x1
# 6121: |kackie,|-->|kackie| x1
# 6135: |henry,|-->|henry| x1
# 6178: |andrea,|-->|andrea| x1
# 6227: |boutell,|-->|boutell| x1
# 6243: |maguire,|-->|maguire| x1
# 6246: |steve,|-->|steve| x1
# 6273: |sullivan,|-->|sullivan| x1
# 6376: |krysztof,|-->|krysztof| x1
# 6433: |seymour,|-->|seymour| x1
# 6564: |johansson,|-->|johansson| x1
# 6626: |ralph,|-->|ralph| x1
# 6689: |dunn,|-->|dunn| x1
# 6872: |blank,|-->|blank| x1
# 6987: |maybury,|-->|maybury| x1
# 7031: |landau,|-->|landau| x1
# 7085: |dharma,|-->|dharma| x1
# 7121: |wium,|-->|wium| x1
# 7181: |lars,|-->|lars| x1
# 7276: |sheriff,|-->|sheriff| x1
# 7330: |ford,|-->|ford| x1
# 7479: |szor,|-->|szor| x1
# 7495: |monds,|-->|monds| x1
# 7514: |nantz,|-->|nantz| x1
# 7677: |stroustrup,|-->|stroustrup| x1
# 7778: |jyri,|-->|jyri| x1
# 7797: |hofmann,|-->|hofmann| x1
# 7801: |alston,|-->|alston| x1
# 7840: |crispin,|-->|crispin| x1
# 7851: |pittman,|-->|pittman| x1
# 7995: |chen,|-->|chen| x1
# 8017: |northover,|-->|northover| x1
# 8059: |albert,|-->|albert| x1
# 8063: |koenig,|-->|koenig| x1
# 8085: |rob,|-->|rob| x1
# 8174: |motwani,|-->|motwani| x1
# 8241: |scambray,|-->|scambray| x1
# 8419: |estevez,|-->|estevez| x1
# 8531: |wysopal,|-->|wysopal| x1
# 8571: |dean,|-->|dean| x1
# 8657: |hall,|-->|hall| x1
# 8726: |rebecca,|-->|rebecca| x1
# 8823: |tzilla,|-->|tzilla| x1
# 8840: |kent,|-->|kent| x1
# 8857: |xiang,|-->|xiang| x1
# 8877: |christine,|-->|christine| x1
# 8966: |joshua,|-->|joshua| x1
# 8982: |vijay,|-->|vijay| x1
# 9019: |aho,|-->|aho| x1
# 9022: |violleau,|-->|violleau| x1
# 9101: |shinn,|-->|shinn| x1
# 9391: |jonathan,|-->|jonathan| x1
# 9536: |mughal,|-->|mughal| x1
# 9649: |dowd,|-->|dowd| x1
# 9655: |kozaczynski,|-->|kozaczynski| x1
# 9718: |naik,|-->|naik| x1
# 10088: |hamlet,|-->|hamlet| x1
# 10120: |bleeker,|-->|bleeker| x1
# 10137: |ira,|-->|ira| x1
# 10191: |danny,|-->|danny| x1
# 10254: |hammond,|-->|hammond| x1
# 10289: |hearn,|-->|hearn| x1
# 10292: |date,|-->|date| x1
# 10352: |clovis,|-->|clovis| x1
# 10403: |haigh,|-->|haigh| x1
# 10511: |clive,|-->|clive| x1
# 10550: |jayson,|-->|jayson| x1
# 10591: |andy,|-->|andy| x1
# 10697: |bederson,|-->|bederson| x1
# 10712: |brian,|-->|brian| x1
# 10828: |vaughn,|-->|vaughn| x1
# 10949: |doyle,|-->|doyle| x1
# 10954: |butler,|-->|butler| x1
# 11051: |william,|-->|william| x1
# 11092: |thierry,|-->|thierry| x1
# 11223: |gafter,|-->|gafter| x1
# 11326: |bernstein,|-->|bernstein| x1
# 11534: |ware,|-->|ware| x1
# 11548: |dwivedi,|-->|dwivedi| x1
# 11689: |freytag,|-->|freytag| x1
# 12049: |mcconnell,|-->|mcconnell| x1
# 12106: |miller,|-->|miller| x1
# 12150: |spitzner,|-->|spitzner| x1
# 12181: |rigaux,|-->|rigaux| x1
# 12189: |hinkle,|-->|hinkle| x1
# 12203: |anderson,|-->|anderson| x1
# 12243: |nicholas,|-->|nicholas| x1
# 12332: |kochmer,|-->|kochmer| x1
# 12365: |bonnet,|-->|bonnet| x1
# 12574: |partridge,|-->|partridge| x1
# 12625: |andreas,|-->|andreas| x1
# 12763: |visk,|-->|visk| x1
# 12848: |balch,|-->|balch| x1
# 12938: |kaminow,|-->|kaminow| x1
# 13187: |thomas,|-->|thomas| x1
# 13257: |becker,|-->|becker| x1
# 13319: |spool,|-->|spool| x1
# 13329: |russell,|-->|russell| x1
# 13520: |liebeherr,|-->|liebeherr| x1
# 13530: |jason,|-->|jason| x1
# 13558: |haggar,|-->|haggar| x1
# 13581: |halsall,|-->|halsall| x1
# 13680: |kruchten,|-->|kruchten| x1
# 13715: |feghhi,|-->|feghhi| x1
# 13734: |russ,|-->|russ| x1
# 13824: |hopcroft,|-->|hopcroft| x1
# 13971: |rosanna,|-->|rosanna| x1
# 13980: |gudgin,|-->|gudgin| x1
# 14237: |leffingwell,|-->|leffingwell| x1
# 14328: |frank,|-->|frank| x1
# 14421: |alistair,|-->|alistair| x1
# 14431: |mcmanus,|-->|mcmanus| x1
# 14437: |carl,|-->|carl| x1
# 14490: |pindyck,|-->|pindyck| x1
# 14494: |pankaj,|-->|pankaj| x1
# 14624: |bramble,|-->|bramble| x1
# 14627: |pols,|-->|pols| x1
# 14736: |weiss,|-->|weiss| x1
# 14777: |khalid,|-->|khalid| x1
# 14871: |makoto,|-->|makoto| x1
# 14967: |bo,|-->|bo| x1
# 14977: |ce,|-->|ce| x1
# 14994: |whittaker,|-->|whittaker| x1
# 15112: |hohmann,|-->|hohmann| x1
# 15182: |dov,|-->|dov| x1
# 15200: |scot,|-->|scot| x1
# 15290: |ginsburg,|-->|ginsburg| x1
# 15449: |rubinfeld,|-->|rubinfeld| x1
# 15569: |hirschbuhl,|-->|hirschbuhl| x1
# 15579: |williams,|-->|williams| x1
# 15603: |bryce,|-->|bryce| x1
# 15630: |sethi,|-->|sethi| x1
# 15634: |keshav,|-->|keshav| x1
# 15672: |paulish,|-->|paulish| x1
# 15885: |adrian,|-->|adrian| x1
# 15926: |budd,|-->|budd| x1
# 15952: |tabaka,|-->|tabaka| x1
# 15965: |kazlauskas,|-->|kazlauskas| x1
# 16045: |shah,|-->|shah| x1
# 16063: |robillard,|-->|robillard| x1
# 16183: |george,|-->|george| x1
# 16215: |valade,|-->|valade| x1
# 16274: |schwarz,|-->|schwarz| x1
# 16327: |kyle,|-->|kyle| x1
# 16411: |kramer,|-->|kramer| x1
# 16419: |smedinghoff,|-->|smedinghoff| x1
# 16485: |gurtovoy,|-->|gurtovoy| x1
# 16605: |auer,|-->|auer| x1
# 16701: |hamburger,|-->|hamburger| x1
# 16843: |awais,|-->|awais| x1
# 16857: |kemp,|-->|kemp| x1
# 16881: |rescorla,|-->|rescorla| x1
# 16953: |lomow,|-->|lomow| x1
# 16986: |kenan,|-->|kenan| x1
# 17216: |scott,|-->|scott| x1
# 17225: |andrei,|-->|andrei| x1
# 17492: |bulka,|-->|bulka| x1
# 17561: |lillian,|-->|lillian| x1
# 17585: |lehnert,|-->|lehnert| x1
# 17632: |guzdial,|-->|guzdial| x1
# 17749: |weafer,|-->|weafer| x1
# 17846: |carlisle,|-->|carlisle| x1
# 17946: |wright,|-->|wright| x1
# 18082: |egan,|-->|egan| x1
# 18180: |kevin,|-->|kevin| x1
# 18457: |cline,|-->|cline| x1
# 18539: |rashid,|-->|rashid| x1
# 18599: |kip,|-->|kip| x1
# 18608: |l,|-->|l| x1
# 18711: |fabian,|-->|fabian| x1
# 18759: |ambler,|-->|ambler| x1
# 18930: |dietrich,|-->|dietrich| x1
# 18981: |hiroshi,|-->|hiroshi| x1
# 18992: |bowie,|-->|bowie| x1
# 19016: |witten,|-->|witten| x1
# 19089: |horstmann,|-->|horstmann| x1
# 19134: |ling,|-->|ling| x1
# 19241: |aaron,|-->|aaron| x1
# 19280: |jared,|-->|jared| x1
# 19281: |chapple,|-->|chapple| x1
# 19291: |kathy,|-->|kathy| x1
# 19296: |schoonover,|-->|schoonover| x1
# 19462: |team,|-->|team| x1
# 19474: |gupta,|-->|gupta| x1
# 19488: |schmidt,|-->|schmidt| x1
# 19647: |sharma,|-->|sharma| x1
# 19725: |royal,|-->|royal| x1
# 19822: |marasco,|-->|marasco| x1
# 19892: |noyes,|-->|noyes| x1
# 19895: |zvi,|-->|zvi| x1
# 20030: |project,|-->|project| x1
# 20033: |sakari,|-->|sakari| x1
# 20038: |seitsonen,|-->|seitsonen| x1
# 20041: |kouti,|-->|kouti| x1
# 20160: |deza,|-->|deza| x1
# 20270: |tan,|-->|tan| x1
# 20381: |appelquist,|-->|appelquist| x1
# 20474: |dechter,|-->|dechter| x1
# 20508: |guy,|-->|guy| x1
# 20699: |cushman,|-->|cushman| x1
# 20711: |carroll,|-->|carroll| x1
# 21192: |watson,|-->|watson| x1
# 21202: |watkins,|-->|watkins| x1
# 21348: |siobhan,|-->|siobhan| x1
# 21579: |macisaac,|-->|macisaac| x1
# 21596: |nick,|-->|nick| x1
# 21868: |bimbo,|-->|bimbo| x1
# 21901: |piemonte,|-->|piemonte| x1
# 21970: |albing,|-->|albing| x1
# 22040: |raskin,|-->|raskin| x1
# 22274: |roiger,|-->|roiger| x1
# 22325: |stuart,|-->|stuart| x1
# 22672: |mccarthy,|-->|mccarthy| x1
# 22708: |naohiko,|-->|naohiko| x1
# 22943: |ken,|-->|ken| x1
# 23065: |farin,|-->|farin| x1
# 23136: |shreeraj,|-->|shreeraj| x1
# 23363: |zakhour,|-->|zakhour| x1
# 23367: |hommel,|-->|hommel| x1
# 23369: |melton,|-->|melton| x1
# 23378: |spears,|-->|spears| x1
# 23403: |maier,|-->|maier| x1
# Sample Applications:
# lippman, stanley b.; moo, barbara e.; lajoie, josee; lajoie, jose --- lippman stanley b et al
# knuth, donald e. --- knuth donald
# james d. foley, andries van dam, steven k. feiner, john f. hughes --- james d. foley andries van dam steven k. feiner john f. hughes
# carter, eric, lippert, eric --- carter, eric lippert, eric
# triad, interactive --- triad interactive
# huston, stephen d.johnson, james cesyyid, umar --- huston stephen d. et al
# michael juntao yuan, kevin sharp --- michael juntao yuan kevin sharp
# shelford, thomas j --- shelford thomas
# denning, dorothy e. --- denning dorothy
# margaret a. ellis, bjarne stroustrup --- margaret a. ellis bjarne stroustrup
#
# number of rules in this group: 433
# max count: 993
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
