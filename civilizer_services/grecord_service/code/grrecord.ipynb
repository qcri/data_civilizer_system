# %%
from call_goldenrecord import main as M

# %%
input_file = "../data/mitdwh/"
output_file = "./mitdwh_updated.csv"

# %%
M(input_file, output_file)
# Out:
# looking for rules for table less_cluster.csv at column 1
# number of clusters 6366
# avg size 5.3415
# column: facroomkey
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 2
# number of clusters 6366
# avg size 5.3415
# column: building key
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 3
# number of clusters 6366
# avg size 5.3415
# column: room
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 4
# number of clusters 6366
# avg size 5.3415
# column: mit id
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 5
# number of clusters 6366
# avg size 5.3415
# column: name
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 6
# number of clusters 6366
# avg size 5.3415
# column: officelocation
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 5
# Number of Rules Generated: 29
# Number of Rules In Use: 23
# Number of Groups: 23
#
#
#
# group: ------
# [$UNIQUE_PATH$, 103, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 2: |e18-369|-->|2-106| x2
# Sample Applications:
# e18-369 --- 2-106
#
# number of rules in this group: 1
# max count: 2
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 0 groups:
# 1[1], 2[6335], 3[30],
# number of duplicates: 30
#
#
#
# group: ------
# [$UNIQUE_PATH$, 102, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 1: |e18-369|-->|2-174| x2
# Sample Applications:
# e18-369 --- 2-174
#
# number of rules in this group: 1
# max count: 2
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 1 groups:
# 1[1], 2[6337], 3[28],
# number of duplicates: 28
#
#
#
# group: ------
# [$UNIQUE_PATH$, 101, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 0: |e17-417|-->|2-180| x2
# Sample Applications:
# e17-417 --- 2-180
#
# number of rules in this group: 1
# max count: 2
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 2 groups:
# 1[1], 2[6339], 3[26],
# number of duplicates: 26
#
#
#
# group: ------
# [$UNIQUE_PATH$, 123, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 22: |e18-378|-->|2-181| x1
# Sample Applications:
# e18-378 --- 2-181
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 3 groups:
# 1[1], 2[6340], 3[25],
# number of duplicates: 25
#
#
#
# group: ------
# [$UNIQUE_PATH$, 122, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 21: |e18-414|-->|2-276| x1
# Sample Applications:
# e18-414 --- 2-276
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 4 groups:
# 1[1], 2[6341], 3[24],
# number of duplicates: 24
#
#
#
# group: ------
# [$UNIQUE_PATH$, 121, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 20: |e17-416|-->|2-345| x1
# Sample Applications:
# e17-416 --- 2-345
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 5 groups:
# 1[1], 2[6342], 3[23],
# number of duplicates: 23
#
#
#
# group: ------
# [$UNIQUE_PATH$, 120, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 19: |e18-478|-->|2-241| x1
# Sample Applications:
# e18-478 --- 2-241
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 6 groups:
# 1[1], 2[6343], 3[22],
# number of duplicates: 22
#
#
#
# group: ------
# [$UNIQUE_PATH$, 119, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 18: |e18-304|-->|2-169| x1
# Sample Applications:
# e18-304 --- 2-169
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 7 groups:
# 1[1], 2[6344], 3[21],
# number of duplicates: 21
#
#
#
# group: ------
# [$UNIQUE_PATH$, 118, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 17: |e17-338|-->|2-172| x1
# Sample Applications:
# e17-338 --- 2-172
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 8 groups:
# 1[1], 2[6345], 3[20],
# number of duplicates: 20
#
#
#
# group: ------
# [$UNIQUE_PATH$, 117, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 16: |e17-316|-->|2-279| x1
# Sample Applications:
# e17-316 --- 2-279
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 9 groups:
# 1[1], 2[6346], 3[19],
# number of duplicates: 19
#
#
#
# group: ------
# [$UNIQUE_PATH$, 116, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 15: |e17-314|-->|2-278| x1
# Sample Applications:
# e17-314 --- 2-278
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
#
# After applying 10 groups:
# 1[1], 2[6346], 3[19],
# number of duplicates: 19
#
#
#
# group: ------
# [$UNIQUE_PATH$, 116, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 15: |e17-314|-->|2-278| x1
# Sample Applications:
# e17-314 --- 2-278
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 11 groups:
# 1[1], 2[6347], 3[18],
# number of duplicates: 18
#
#
#
# group: ------
# [$UNIQUE_PATH$, 115, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 14: |e17-324|-->|2-375| x1
# Sample Applications:
# e17-324 --- 2-375
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 12 groups:
# 1[1], 2[6348], 3[17],
# number of duplicates: 17
#
#
#
# group: ------
# [$UNIQUE_PATH$, 114, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 13: |e18-312|-->|2-274| x1
# Sample Applications:
# e18-312 --- 2-274
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 13 groups:
# 1[1], 2[6349], 3[16],
# number of duplicates: 16
#
#
#
# group: ------
# [$UNIQUE_PATH$, 113, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 12: |e18-478|-->|2-165| x1
# Sample Applications:
# e18-478 --- 2-165
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 14 groups:
# 1[1], 2[6350], 3[15],
# number of duplicates: 15
#
#
#
# group: ------
# [$UNIQUE_PATH$, 112, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 11: |e18-369|-->|2-178| x1
# Sample Applications:
# e18-369 --- 2-178
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 15 groups:
# 1[1], 2[6351], 3[14],
# number of duplicates: 14
#
#
#
# group: ------
# [$UNIQUE_PATH$, 111, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 10: |e17-344|-->|2-371| x1
# Sample Applications:
# e17-344 --- 2-371
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 16 groups:
# 1[1], 2[6352], 3[13],
# number of duplicates: 13
#
#
#
# group: ------
# [$UNIQUE_PATH$, 110, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 9: |e18-424|-->|2-273| x1
# Sample Applications:
# e18-424 --- 2-273
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 17 groups:
# 1[1], 2[6353], 3[12],
# number of duplicates: 12
#
#
#
# group: ------
# [$UNIQUE_PATH$, 109, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 8: |e17-430|-->|2-282| x1
# Sample Applications:
# e17-430 --- 2-282
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 18 groups:
# 1[1], 2[6354], 3[11],
# number of duplicates: 11
#
#
#
# group: ------
# [$UNIQUE_PATH$, 108, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 7: |e17-440|-->|2-280| x1
# Sample Applications:
# e17-440 --- 2-280
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 19 groups:
# 1[1], 2[6355], 3[10],
# number of duplicates: 10
#
#
#
# group: ------
# [$UNIQUE_PATH$, 107, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 6: |e18-469|-->|2-155| x1
# Sample Applications:
# e18-469 --- 2-155
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 20 groups:
# 1[1], 2[6356], 3[9],
# number of duplicates: 9
#
#
#
# group: ------
# [$UNIQUE_PATH$, 106, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 5: |e18-326|-->|2-270| x1
# Sample Applications:
# e18-326 --- 2-270
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 21 groups:
# 1[1], 2[6357], 3[8],
# number of duplicates: 8
#
#
#
# group: ------
# [$UNIQUE_PATH$, 105, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 4: |e17-434|-->|2-377| x1
# Sample Applications:
# e17-434 --- 2-377
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 22 groups:
# 1[1], 2[6358], 3[7],
# number of duplicates: 7
#
#
#
# group: ------
# [$UNIQUE_PATH$, 104, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 3: |e17-404|-->|2-370| x1
# Sample Applications:
# e17-404 --- 2-370
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 23 groups:
# 1[1], 2[6359], 3[6],
# number of duplicates: 6
#
#
#
# Done with current column
#
# looking for rules for table less_cluster.csv at column 7
# number of clusters 6366
# avg size 5.3415
# column: office phone
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 1
# Number of Rules Generated: 5
# Number of Rules In Use: 5
# Number of Groups: 5
#
#
#
# group: ------
# [$UNIQUE_PATH$, 105, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 4: |6173245267|-->|6172534986| x1
# Sample Applications:
# 6173245267 --- 6172534986
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 0 groups:
# 1[1435], 2[4927], 3[4],
# number of duplicates: 4
#
#
#
# group: ------
# [$UNIQUE_PATH$, 104, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 3: |9176475099|-->|6172536502| x1
# Sample Applications:
# 9176475099 --- 6172536502
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 1 groups:
# 1[1435], 2[4928], 3[3],
# number of duplicates: 3
#
#
#
# group: ------
# [$UNIQUE_PATH$, 103, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 2: |6174358265|-->|3105950528| x1
# Sample Applications:
# 6174358265 --- 3105950528
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 2 groups:
# 1[1435], 2[4929], 3[2],
# number of duplicates: 2
#
#
#
# group: ------
# [$UNIQUE_PATH$, 102, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 1: |6172537940|-->|6172535010| x1
# Sample Applications:
# 6172537940 --- 6172535010
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 3 groups:
# 1[1435], 2[4930], 3[1],
# number of duplicates: 1
#
#
#
# group: ------
# [$UNIQUE_PATH$, 101, Capitals, 0] --- [$UNIQUE_PATH$, 101, Capitals, 0]
#
#
# 0: |6174522103|-->|6172587282| x1
# Sample Applications:
# 6174522103 --- 6172587282
#
# number of rules in this group: 1
# max count: 1
# ------------
#
# 0: do not apply all of them;  1: apply them to all;  2: apply them reversely; 3: postpone;  4; exit
#
# 1
# After applying 4 groups:
# 1[1435], 2[4931],
# number of duplicates: 0
#
#
#
# Done with current column
#
# looking for rules for table less_cluster.csv at column 8
# number of clusters 6366
# avg size 5.3415
# column: directory title
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 1
# Number of Rules Generated: 60
# Number of Rules In Use: 0
# Number of Groups: 0
#
#
#
# Done with current column
#
# looking for rules for table less_cluster.csv at column 9
# number of clusters 6366
# avg size 5.3415
# column: departmentnumber
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 10
# number of clusters 6366
# avg size 5.3415
# column: departmentname
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 1
# Number of Rules Generated: 0
# Number of Rules In Use: 0
# Number of Groups: 0
#
#
#
# Done with current column
#
# looking for rules for table less_cluster.csv at column 11
# number of clusters 6366
# avg size 5.3415
# column: email address
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 5
# Number of Rules Generated: 5
# Number of Rules In Use: 0
# Number of Groups: 0
#
#
#
# Done with current column
#
# looking for rules for table less_cluster.csv at column 12
# number of clusters 6366
# avg size 5.3415
# column: departmentcode
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 13
# number of clusters 6366
# avg size 5.3415
# column: departmentname
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 14
# number of clusters 6366
# avg size 5.3415
# column: departmentfullname
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 15
# number of clusters 6366
# avg size 5.3415
# column: schoolcode
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 16
# number of clusters 6366
# avg size 5.3415
# column: schoolname
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 17
# number of clusters 6366
# avg size 5.3415
# column: deptbudgetcode
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 18
# number of clusters 6366
# avg size 5.3415
# column: deptnameincommencementbk
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# looking for rules for table less_cluster.csv at column 19
# number of clusters 6366
# avg size 5.3415
# column: schoolnameincommencementbk
# option: 0 (default): skip,
# 1: replacing rule only,
# 2: replacing rules + full rules,
# 3: replacing rules + deletion rules,
# 4: replacing rules + deletion rules + full rules,
# 5: full rules only
#
# 0
# Successfully Exit!

# %%
import pandas as pd

# %%
df = pd.read_csv("mitdwh_updated.csv", encoding='latin1')
# Out:
# /Users/ra-mit/development/virtualenvs/discovery/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#              cluster_id facroomkey building key  room       mit id  \
# 0                   NaN        NaN          NaN   NaN          NaN
# 1             900000197     56-275           56   275  900000197.0
# 2                   NaN        NaN          NaN   NaN          NaN
# 3             900000197     56-275           56   275  900000197.0
# 4                   NaN        NaN          NaN   NaN          NaN
# 5             900000197     56-275           56   275  900000197.0
# 6                   NaN        NaN          NaN   NaN          NaN
# 7             900000213     31-155           31   155  900000213.0
# 8                   NaN        NaN          NaN   NaN          NaN
# 9             900000213     31-155           31   155  900000213.0
# 10                  NaN        NaN          NaN   NaN          NaN
# 11            900000213     31-155           31   155  900000213.0
# 12                  NaN        NaN          NaN   NaN          NaN
# 13            900000290    54-1120           54  1120  900000290.0
# 14                  NaN        NaN          NaN   NaN          NaN
# 15            900000290    54-1120           54  1120  900000290.0
# 16                  NaN        NaN          NaN   NaN          NaN
# 17            900000290    54-1120           54  1120  900000290.0
# 18                  NaN        NaN          NaN   NaN          NaN
# 19            900000290    54-1120           54  1120  900000290.0
# 20                  NaN        NaN          NaN   NaN          NaN
# 21            900000389    e23-266          e23   266  900000389.0
# 22                  NaN        NaN          NaN   NaN          NaN
# 23            900000498     33-310           33   310  900000498.0
# 24                  NaN        NaN          NaN   NaN          NaN
# 25            900000498     33-310           33   310  900000498.0
# 26                  NaN        NaN          NaN   NaN          NaN
# 27            900000498     33-310           33   310  900000498.0
# 28                  NaN        NaN          NaN   NaN          NaN
# 29            900000504    e23-313          e23   313  900000504.0
# ...                 ...        ...          ...   ...          ...
# 33974               NaN        NaN          NaN   NaN          NaN
# 33975     zhihu@mit.edu     39-629           39   629          NaN
# 33976               NaN        NaN          NaN   NaN          NaN
# 33977     zhixu@mit.edu    32-d666           32  d666          NaN
# 33978               NaN        NaN          NaN   NaN          NaN
# 33979  zhiyongl@mit.edu     54-216           54   216          NaN
# 33980               NaN        NaN          NaN   NaN          NaN
# 33981   zhongyi@mit.edu      5-424            5   424          NaN
# 33982               NaN        NaN          NaN   NaN          NaN
# 33983   zhou008@mit.edu    32-g770           32  g770          NaN
# 33984               NaN        NaN          NaN   NaN          NaN
# 33985    ziedbc@mit.edu    32-d666           32  d666          NaN
# 33986               NaN        NaN          NaN   NaN          NaN
# 33987   zjburas@mit.edu    e18-509          e18   509          NaN
# 33988               NaN        NaN          NaN   NaN          NaN
# 33989       zjt@mit.edu   ne47-577         ne47   577          NaN
# 33990               NaN        NaN          NaN   NaN          NaN
# 33991  zlateski@mit.edu    46-5065           46  5065          NaN
# 33992               NaN        NaN          NaN   NaN          NaN
# 33993    zliu14@mit.edu    32-d674           32  d674          NaN
# 33994               NaN        NaN          NaN   NaN          NaN
# 33995      zoki@mit.edu    32-d472           32  d472          NaN
# 33996               NaN        NaN          NaN   NaN          NaN
# 33997     zsong@mit.edu  nw14-2317         nw14  2317          NaN
# 33998               NaN        NaN          NaN   NaN          NaN
# 33999  zubeldia@mit.edu    32-d666           32  d666          NaN
# 34000               NaN        NaN          NaN   NaN          NaN
# 34001      zygu@mit.edu     66-465           66   465          NaN
# 34002               NaN        NaN          NaN   NaN          NaN
# 34003     zzhan@mit.edu    54-1717           54  1717          NaN
#
#                           name officelocation  office phone  \
# 0                          NaN            NaN           NaN
# 1                 quimby, john         56-275  6.172533e+09
# 2                          NaN            NaN           NaN
# 3                          NaN         56-275  6.172533e+09
# 4                          NaN            NaN           NaN
# 5                 quimby, john         56-275           NaN
# 6                          NaN            NaN           NaN
# 7               wong, victor w         31-155  6.172535e+09
# 8                          NaN            NaN           NaN
# 9                          NaN         31-155  6.172535e+09
# 10                         NaN            NaN           NaN
# 11              wong, victor w         31-155           NaN
# 12                         NaN            NaN           NaN
# 13           bowring, samuel a        54-1120  6.172534e+09
# 14                         NaN            NaN           NaN
# 15           bowring, samuel a        54-1120  6.172534e+09
# 16                         NaN            NaN           NaN
# 17                         NaN        54-1120  6.172534e+09
# 18                         NaN            NaN           NaN
# 19                         NaN        54-1120  6.172534e+09
# 20                         NaN            NaN           NaN
# 21          garston, matthew j        e23-266  6.172534e+09
# 22                         NaN            NaN           NaN
# 23              lagace, paul a         33-310  6.172534e+09
# 24                         NaN            NaN           NaN
# 25                         NaN         33-310  6.172534e+09
# 26                         NaN            NaN           NaN
# 27              lagace, paul a         33-310           NaN
# 28                         NaN            NaN           NaN
# 29             raymond, gloria        e23-313  6.172534e+09
# ...                        ...            ...           ...
# 33974                      NaN            NaN           NaN
# 33975                  hu, zhi         39-629  2.530728e+06
# 33976                      NaN            NaN           NaN
# 33977                  xu, zhi        32-d666  9.098116e+06
# 33978                      NaN            NaN           NaN
# 33979              li, zhiyong         54-216           NaN
# 33980                      NaN            NaN           NaN
# 33981            wan, zhong yi          5-424  3.247509e+06
# 33982                      NaN            NaN           NaN
# 33983                 zhou, mo        32-g770           NaN
# 33984                      NaN            NaN           NaN
# 33985        ben chaouch, zied        32-d666           NaN
# 33986                      NaN            NaN           NaN
# 33987           buras, zachary        e18-509  2.535370e+06
# 33988                      NaN            NaN           NaN
# 33989           tan, zheng jie       ne47-577           NaN
# 33990                      NaN            NaN           NaN
# 33991     zlateski, aleksandar        46-5065           NaN
# 33992                      NaN            NaN           NaN
# 33993              liu, zhenyu        32-d674           NaN
# 33994                      NaN            NaN           NaN
# 33995            dzunic, zoran        32-d472  4.522124e+06
# 33996                      NaN            NaN           NaN
# 33997            song, zhigang      nw14-2317           NaN
# 33998                      NaN            NaN           NaN
# 33999  zubeldia suarez, martin        32-d666           NaN
# 34000                      NaN            NaN           NaN
# 34001               gu, zongyu         66-465           NaN
# 34002                      NaN            NaN           NaN
# 34003           zhan, zhuchang        54-1717           NaN
#
#                              directory title  departmentnumber  \
# 0                                        NaN               NaN
# 1                         research scientist          151000.0
# 2                                        NaN               NaN
# 3                         research scientist               NaN
# 4                                        NaN               NaN
# 5                         research scientist               NaN
# 6                                        NaN               NaN
# 7               principal research scientist           65000.0
# 8                                        NaN               NaN
# 9               principal research scientist               NaN
# 10                                       NaN               NaN
# 11              principal research scientist               NaN
# 12                                       NaN               NaN
# 13     robert r. shrock professor of geology          153000.0
# 14                                       NaN               NaN
# 15     robert r. shrock professor of geology          153000.0
# 16                                       NaN               NaN
# 17     robert r. shrock professor of geology               NaN
# 18                                       NaN               NaN
# 19     robert r. shrock professor of geology               NaN
# 20                                       NaN               NaN
# 21                               optometrist          495000.0
# 22                                       NaN               NaN
# 23                                 professor           61000.0
# 24                                       NaN               NaN
# 25                                 professor               NaN
# 26                                       NaN               NaN
# 27                                 professor               NaN
# 28                                       NaN               NaN
# 29     manager, budget analysis & purchasing          495000.0
# ...                                      ...               ...
# 33974                                    NaN               NaN
# 33975                                    NaN               NaN
# 33976                                    NaN               NaN
# 33977                                    NaN               NaN
# 33978                                    NaN               NaN
# 33979                                    NaN               NaN
# 33980                                    NaN               NaN
# 33981                                    NaN               NaN
# 33982                                    NaN               NaN
# 33983                                    NaN               NaN
# 33984                                    NaN               NaN
# 33985                                    NaN               NaN
# 33986                                    NaN               NaN
# 33987                                    NaN               NaN
# 33988                                    NaN               NaN
# 33989                                    NaN               NaN
# 33990                                    NaN               NaN
# 33991                                    NaN               NaN
# 33992                                    NaN               NaN
# 33993                                    NaN               NaN
# 33994                                    NaN               NaN
# 33995                                    NaN               NaN
# 33996                                    NaN               NaN
# 33997                                    NaN               NaN
# 33998                                    NaN               NaN
# 33999                                    NaN               NaN
# 34000                                    NaN               NaN
# 34001                                    NaN               NaN
# 34002                                    NaN               NaN
# 34003                                    NaN               NaN
#
#                                          departmentname     email address  \
# 0                                                   NaN               NaN
# 1                                 department of biology    quimby@mit.edu
# 2                                                   NaN               NaN
# 3                                                   NaN    quimby@mit.edu
# 4                                                   NaN               NaN
# 5                                                   NaN               NaN
# 6                                                   NaN               NaN
# 7                  department of mechanical engineering     vwong@mit.edu
# 8                                                   NaN               NaN
# 9                                                   NaN     vwong@mit.edu
# 10                                                  NaN               NaN
# 11                                                  NaN               NaN
# 12                                                  NaN               NaN
# 13     dept of earth, atmospheric, & planetary sciences  sbowring@mit.edu
# 14                                                  NaN               NaN
# 15     dept of earth, atmospheric, & planetary sciences  sbowring@mit.edu
# 16                                                  NaN               NaN
# 17                                                  NaN  sbowring@mit.edu
# 18                                                  NaN               NaN
# 19                                                  NaN  sbowring@mit.edu
# 20                                                  NaN               NaN
# 21                                   medical department  gars@med.mit.edu
# 22                                                  NaN               NaN
# 23           department of aeronautics and astronautics       pal@mit.edu
# 24                                                  NaN               NaN
# 25                                                  NaN       pal@mit.edu
# 26                                                  NaN               NaN
# 27                                                  NaN               NaN
# 28                                                  NaN               NaN
# 29                                   medical department  raym@med.mit.edu
# ...                                                 ...               ...
# 33974                                               NaN               NaN
# 33975                                               NaN     zhihu@mit.edu
# 33976                                               NaN               NaN
# 33977                                               NaN     zhixu@mit.edu
# 33978                                               NaN               NaN
# 33979                                               NaN  zhiyongl@mit.edu
# 33980                                               NaN               NaN
# 33981                                               NaN   zhongyi@mit.edu
# 33982                                               NaN               NaN
# 33983                                               NaN   zhou008@mit.edu
# 33984                                               NaN               NaN
# 33985                                               NaN    ziedbc@mit.edu
# 33986                                               NaN               NaN
# 33987                                               NaN   zjburas@mit.edu
# 33988                                               NaN               NaN
# 33989                                               NaN       zjt@mit.edu
# 33990                                               NaN               NaN
# 33991                                               NaN  zlateski@mit.edu
# 33992                                               NaN               NaN
# 33993                                               NaN    zliu14@mit.edu
# 33994                                               NaN               NaN
# 33995                                               NaN      zoki@mit.edu
# 33996                                               NaN               NaN
# 33997                                               NaN     zsong@mit.edu
# 33998                                               NaN               NaN
# 33999                                               NaN  zubeldia@mit.edu
# 34000                                               NaN               NaN
# 34001                                               NaN      zygu@mit.edu
# 34002                                               NaN               NaN
# 34003                                               NaN     zzhan@mit.edu
#
#       departmentcode                departmentname.1  \
# 0                NaN                             NaN
# 1                  7                         biology
# 2                NaN                             NaN
# 3                  7                         biology
# 4                NaN                             NaN
# 5                  7                         biology
# 6                NaN                             NaN
# 7                  2          mechanical engineering
# 8                NaN                             NaN
# 9                  2          mechanical engineering
# 10               NaN                             NaN
# 11                 2          mechanical engineering
# 12               NaN                             NaN
# 13                12    earth, atmos & planetary sci
# 14               NaN                             NaN
# 15                19  meteorology & physical oceanog
# 16               NaN                             NaN
# 17                12    earth, atmos & planetary sci
# 18               NaN                             NaN
# 19                19  meteorology & physical oceanog
# 20               NaN                             NaN
# 21               med              medical department
# 22               NaN                             NaN
# 23                16    aeronautics and astronautics
# 24               NaN                             NaN
# 25                16    aeronautics and astronautics
# 26               NaN                             NaN
# 27                16    aeronautics and astronautics
# 28               NaN                             NaN
# 29               med              medical department
# ...              ...                             ...
# 33974            NaN                             NaN
# 33975              6   electrical eng & computer sci
# 33976            NaN                             NaN
# 33977              6   electrical eng & computer sci
# 33978            NaN                             NaN
# 33979             12    earth, atmos & planetary sci
# 33980            NaN                             NaN
# 33981            cdo    computation for des & optmiz
# 33982            NaN                             NaN
# 33983              6   electrical eng & computer sci
# 33984            NaN                             NaN
# 33985              6   electrical eng & computer sci
# 33986            NaN                             NaN
# 33987             10            chemical engineering
# 33988            NaN                             NaN
# 33989              3       materials science and eng
# 33990            NaN                             NaN
# 33991              6   electrical eng & computer sci
# 33992            NaN                             NaN
# 33993             16    aeronautics and astronautics
# 33994            NaN                             NaN
# 33995              6   electrical eng & computer sci
# 33996            NaN                             NaN
# 33997             22             nuclear engineering
# 33998            NaN                             NaN
# 33999              6   electrical eng & computer sci
# 34000            NaN                             NaN
# 34001             10            chemical engineering
# 34002            NaN                             NaN
# 34003             12    earth, atmos & planetary sci
#
#                        departmentfullname schoolcode         schoolname  \
# 0                                     NaN        NaN                NaN
# 1                              7 -biology          s            science
# 2                                     NaN        NaN                NaN
# 3                              7 -biology          s            science
# 4                                     NaN        NaN                NaN
# 5                              7 -biology          s            science
# 6                                     NaN        NaN                NaN
# 7               2 -mechanical engineering          e        engineering
# 8                                     NaN        NaN                NaN
# 9               2 -mechanical engineering          e        engineering
# 10                                    NaN        NaN                NaN
# 11              2 -mechanical engineering          e        engineering
# 12                                    NaN        NaN                NaN
# 13       12 -earth, atmos & planetary sci          s            science
# 14                                    NaN        NaN                NaN
# 15     19 -meteorology & physical oceanog          s            science
# 16                                    NaN        NaN                NaN
# 17       12 -earth, atmos & planetary sci          s            science
# 18                                    NaN        NaN                NaN
# 19     19 -meteorology & physical oceanog          s            science
# 20                                    NaN        NaN                NaN
# 21                med -medical department          x  mit, non-academic
# 22                                    NaN        NaN                NaN
# 23       16 -aeronautics and astronautics          e        engineering
# 24                                    NaN        NaN                NaN
# 25       16 -aeronautics and astronautics          e        engineering
# 26                                    NaN        NaN                NaN
# 27       16 -aeronautics and astronautics          e        engineering
# 28                                    NaN        NaN                NaN
# 29                med -medical department          x  mit, non-academic
# ...                                   ...        ...                ...
# 33974                                 NaN        NaN                NaN
# 33975    6 -electrical eng & computer sci          e        engineering
# 33976                                 NaN        NaN                NaN
# 33977    6 -electrical eng & computer sci          e        engineering
# 33978                                 NaN        NaN                NaN
# 33979    12 -earth, atmos & planetary sci          s            science
# 33980                                 NaN        NaN                NaN
# 33981   cdo -computation for des & optmiz          e        engineering
# 33982                                 NaN        NaN                NaN
# 33983    6 -electrical eng & computer sci          e        engineering
# 33984                                 NaN        NaN                NaN
# 33985    6 -electrical eng & computer sci          e        engineering
# 33986                                 NaN        NaN                NaN
# 33987            10 -chemical engineering          e        engineering
# 33988                                 NaN        NaN                NaN
# 33989        3 -materials science and eng          e        engineering
# 33990                                 NaN        NaN                NaN
# 33991    6 -electrical eng & computer sci          e        engineering
# 33992                                 NaN        NaN                NaN
# 33993    16 -aeronautics and astronautics          e        engineering
# 33994                                 NaN        NaN                NaN
# 33995    6 -electrical eng & computer sci          e        engineering
# 33996                                 NaN        NaN                NaN
# 33997             22 -nuclear engineering          e        engineering
# 33998                                 NaN        NaN                NaN
# 33999    6 -electrical eng & computer sci          e        engineering
# 34000                                 NaN        NaN                NaN
# 34001            10 -chemical engineering          e        engineering
# 34002                                 NaN        NaN                NaN
# 34003    12 -earth, atmos & planetary sci          s            science
#
#        deptbudgetcode                           deptnameincommencementbk  \
# 0                 NaN                                                NaN
# 1            151000.0                              department of biology
# 2                 NaN                                                NaN
# 3            151000.0                              department of biology
# 4                 NaN                                                NaN
# 5            151000.0                              department of biology
# 6                 NaN                                                NaN
# 7             65000.0               department of mechanical engineering
# 8                 NaN                                                NaN
# 9             65000.0               department of mechanical engineering
# 10                NaN                                                NaN
# 11            65000.0               department of mechanical engineering
# 12                NaN                                                NaN
# 13           153000.0  department of earth, atmospheric, and planetar...
# 14                NaN                                                NaN
# 15           153000.0                          department of meteorology
# 16                NaN                                                NaN
# 17           153000.0  department of earth, atmospheric, and planetar...
# 18                NaN                                                NaN
# 19           153000.0                          department of meteorology
# 20                NaN                                                NaN
# 21                NaN                                                NaN
# 22                NaN                                                NaN
# 23            61000.0         department of aeronautics and astronautics
# 24                NaN                                                NaN
# 25            61000.0         department of aeronautics and astronautics
# 26                NaN                                                NaN
# 27            61000.0         department of aeronautics and astronautics
# 28                NaN                                                NaN
# 29                NaN                                                NaN
# ...               ...                                                ...
# 33974             NaN                                                NaN
# 33975         64000.0  department of electrical engineering and compu...
# 33976             NaN                                                NaN
# 33977         64000.0  department of electrical engineering and compu...
# 33978             NaN                                                NaN
# 33979        153000.0  department of earth, atmospheric, and planetar...
# 33980             NaN                                                NaN
# 33981         60000.0  program in computation for design and optimiza...
# 33982             NaN                                                NaN
# 33983         64000.0  department of electrical engineering and compu...
# 33984             NaN                                                NaN
# 33985         64000.0  department of electrical engineering and compu...
# 33986             NaN                                                NaN
# 33987         62000.0                 department of chemical engineering
# 33988             NaN                                                NaN
# 33989         66000.0    department of materials science and engineering
# 33990             NaN                                                NaN
# 33991         64000.0  department of electrical engineering and compu...
# 33992             NaN                                                NaN
# 33993         61000.0         department of aeronautics and astronautics
# 33994             NaN                                                NaN
# 33995         64000.0  department of electrical engineering and compu...
# 33996             NaN                                                NaN
# 33997         68000.0      department of nuclear science and engineering
# 33998             NaN                                                NaN
# 33999         64000.0  department of electrical engineering and compu...
# 34000             NaN                                                NaN
# 34001         62000.0                 department of chemical engineering
# 34002             NaN                                                NaN
# 34003        153000.0  department of earth, atmospheric, and planetar...
#
#       schoolnameincommencementbk
# 0                            NaN
# 1              school of science
# 2                            NaN
# 3              school of science
# 4                            NaN
# 5              school of science
# 6                            NaN
# 7          school of engineering
# 8                            NaN
# 9          school of engineering
# 10                           NaN
# 11         school of engineering
# 12                           NaN
# 13             school of science
# 14                           NaN
# 15             school of science
# 16                           NaN
# 17             school of science
# 18                           NaN
# 19             school of science
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23         school of engineering
# 24                           NaN
# 25         school of engineering
# 26                           NaN
# 27         school of engineering
# 28                           NaN
# 29                           NaN
# ...                          ...
# 33974                        NaN
# 33975      school of engineering
# 33976                        NaN
# 33977      school of engineering
# 33978                        NaN
# 33979          school of science
# 33980                        NaN
# 33981      school of engineering
# 33982                        NaN
# 33983      school of engineering
# 33984                        NaN
# 33985      school of engineering
# 33986                        NaN
# 33987      school of engineering
# 33988                        NaN
# 33989      school of engineering
# 33990                        NaN
# 33991      school of engineering
# 33992                        NaN
# 33993      school of engineering
# 33994                        NaN
# 33995      school of engineering
# 33996                        NaN
# 33997      school of engineering
# 33998                        NaN
# 33999      school of engineering
# 34000                        NaN
# 34001      school of engineering
# 34002                        NaN
# 34003          school of science
#
# [34004 rows x 20 columns]
