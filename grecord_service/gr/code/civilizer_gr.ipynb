# %%
from call_goldenrecord import main as M
import pandas as pd

# %%
import codecs
with codecs.open(r'/app/storage/data_sets/gr/source.txt', encoding='utf-8') as pathfile:
    input_file = pathfile.readlines()[0].strip()
with codecs.open(r'/app/storage/data_sets/gr/destination.txt', encoding='utf-8') as Ofile:
    output_file = Ofile.readlines()[0]

# %%
m_file = "matches.csv"
file = input_file +  m_file
print(file)
print(output_file)
with open(output_file, "w") as my_empty_csv:
    pass  # or write something to it already

# %%
df = pd.read_csv(file, encoding='latin1')
df.sort_values(['cluster_id'], ascending=[True], inplace=True)

# %%
df[0:50]

# %%
M(input_file, output_file)

# %%
df = pd.read_csv(output_file, encoding='latin1')
df.sort_values(['cluster_id'], ascending=[False], inplace=True)

# %%
df[1:50]
